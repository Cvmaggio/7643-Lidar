# %%
prefix = "lidar-data"
bucket = "sagemaker-us-east-1-224863548990"

# %%
import sagemaker as sage

sess = sage.Session()

# %%
WORK_DIRECTORY = "/tmp/pytorch-example/cifar-10-data"

data_location = sess.upload_data(WORK_DIRECTORY, bucket=bucket, key_prefix=prefix)
# Out:
# ---------------------------------------------------------------------------
# NoSuchBucket                              Traceback (most recent call last)
# File ~/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/transfer.py:288, in S3Transfer.upload_file(self, filename, bucket, key, callback, extra_args)
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/transfer.py?line=286'>287</a> try:
# --> <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/transfer.py?line=287'>288</a>     future.result()
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/transfer.py?line=288'>289</a> # If a client error was raised, add the backwards compatibility layer
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/transfer.py?line=289'>290</a> # that raises a S3UploadFailedError. These specific errors were only
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/transfer.py?line=290'>291</a> # ever thrown for upload_parts but now can be thrown for any related
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/transfer.py?line=291'>292</a> # client error.
#
# File ~/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/futures.py:103, in TransferFuture.result(self)
#      <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/futures.py?line=98'>99</a> try:
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/futures.py?line=99'>100</a>     # Usually the result() method blocks until the transfer is done,
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/futures.py?line=100'>101</a>     # however if a KeyboardInterrupt is raised we want want to exit
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/futures.py?line=101'>102</a>     # out of this and propagate the exception.
# --> <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/futures.py?line=102'>103</a>     return self._coordinator.result()
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/futures.py?line=103'>104</a> except KeyboardInterrupt as e:
#
# File ~/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/futures.py:266, in TransferCoordinator.result(self)
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/futures.py?line=264'>265</a> if self._exception:
# --> <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/futures.py?line=265'>266</a>     raise self._exception
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/futures.py?line=266'>267</a> return self._result
#
# File ~/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/tasks.py:139, in Task.__call__(self)
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/tasks.py?line=137'>138</a>     if not self._transfer_coordinator.done():
# --> <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/tasks.py?line=138'>139</a>         return self._execute_main(kwargs)
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/tasks.py?line=139'>140</a> except Exception as e:
#
# File ~/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/tasks.py:162, in Task._execute_main(self, kwargs)
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/tasks.py?line=159'>160</a> logger.debug(f"Executing task {self} with kwargs {kwargs_to_display}")
# --> <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/tasks.py?line=161'>162</a> return_value = self._main(**kwargs)
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/tasks.py?line=162'>163</a> # If the task is the final task, then set the TransferFuture's
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/tasks.py?line=163'>164</a> # value to the return value from main().
#
# File ~/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/tasks.py:348, in CreateMultipartUploadTask._main(self, client, bucket, key, extra_args)
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/tasks.py?line=346'>347</a> # Create the multipart upload.
# --> <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/tasks.py?line=347'>348</a> response = client.create_multipart_upload(
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/tasks.py?line=348'>349</a>     Bucket=bucket, Key=key, **extra_args
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/tasks.py?line=349'>350</a> )
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/s3transfer/tasks.py?line=350'>351</a> upload_id = response['UploadId']
#
# File ~/miniconda3/envs/7643/lib/python3.9/site-packages/botocore/client.py:395, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/botocore/client.py?line=393'>394</a> # The "self" in this scope is referring to the BaseClient.
# --> <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/botocore/client.py?line=394'>395</a> return self._make_api_call(operation_name, kwargs)
#
# File ~/miniconda3/envs/7643/lib/python3.9/site-packages/botocore/client.py:725, in BaseClient._make_api_call(self, operation_name, api_params)
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/botocore/client.py?line=723'>724</a>     error_class = self.exceptions.from_code(error_code)
# --> <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/botocore/client.py?line=724'>725</a>     raise error_class(parsed_response, operation_name)
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/botocore/client.py?line=725'>726</a> else:
#
# NoSuchBucket: An error occurred (NoSuchBucket) when calling the CreateMultipartUpload operation: The specified bucket does not exist
#
# During handling of the above exception, another exception occurred:
#
# S3UploadFailedError                       Traceback (most recent call last)
# /home/chase/7643-Lidar/remoteDataDownload.ipynb Cell 3' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/chase/7643-Lidar/remoteDataDownload.ipynb#ch0000002?line=0'>1</a> WORK_DIRECTORY = "/tmp/pytorch-example/cifar-10-data"
# ----> <a href='vscode-notebook-cell:/home/chase/7643-Lidar/remoteDataDownload.ipynb#ch0000002?line=2'>3</a> data_location = sess.upload_data(WORK_DIRECTORY, bucket=bucket, key_prefix=prefix)
#
# File ~/miniconda3/envs/7643/lib/python3.9/site-packages/sagemaker/session.py:233, in Session.upload_data(self, path, bucket, key_prefix, extra_args)
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/sagemaker/session.py?line=229'>230</a>     s3 = self.s3_resource
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/sagemaker/session.py?line=231'>232</a> for local_path, s3_key in files:
# --> <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/sagemaker/session.py?line=232'>233</a>     s3.Object(bucket, s3_key).upload_file(local_path, ExtraArgs=extra_args)
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/sagemaker/session.py?line=234'>235</a> s3_uri = "s3://{}/{}".format(bucket, key_prefix)
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/sagemaker/session.py?line=235'>236</a> # If a specific file was used as input (instead of a directory), we return the full S3 key
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/sagemaker/session.py?line=236'>237</a> # of the uploaded object. This prevents unintentionally using other files under the same
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/sagemaker/session.py?line=237'>238</a> # prefix during training.
#
# File ~/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py:318, in object_upload_file(self, Filename, ExtraArgs, Callback, Config)
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=286'>287</a> def object_upload_file(
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=287'>288</a>     self, Filename, ExtraArgs=None, Callback=None, Config=None
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=288'>289</a> ):
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=289'>290</a>     """Upload a file to an S3 object.
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=290'>291</a>
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=291'>292</a>     Usage::
#    (...)
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=315'>316</a>         transfer.
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=316'>317</a>     """
# --> <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=317'>318</a>     return self.meta.client.upload_file(
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=318'>319</a>         Filename=Filename,
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=319'>320</a>         Bucket=self.bucket_name,
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=320'>321</a>         Key=self.key,
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=321'>322</a>         ExtraArgs=ExtraArgs,
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=322'>323</a>         Callback=Callback,
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=323'>324</a>         Config=Config,
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=324'>325</a>     )
#
# File ~/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py:143, in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=107'>108</a> """Upload a file to an S3 object.
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=108'>109</a>
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=109'>110</a> Usage::
#    (...)
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=139'>140</a>     transfer.
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=140'>141</a> """
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=141'>142</a> with S3Transfer(self, Config) as transfer:
# --> <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=142'>143</a>     return transfer.upload_file(
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=143'>144</a>         filename=Filename,
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=144'>145</a>         bucket=Bucket,
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=145'>146</a>         key=Key,
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=146'>147</a>         extra_args=ExtraArgs,
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=147'>148</a>         callback=Callback,
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/inject.py?line=148'>149</a>     )
#
# File ~/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/transfer.py:294, in S3Transfer.upload_file(self, filename, bucket, key, callback, extra_args)
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/transfer.py?line=288'>289</a> # If a client error was raised, add the backwards compatibility layer
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/transfer.py?line=289'>290</a> # that raises a S3UploadFailedError. These specific errors were only
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/transfer.py?line=290'>291</a> # ever thrown for upload_parts but now can be thrown for any related
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/transfer.py?line=291'>292</a> # client error.
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/transfer.py?line=292'>293</a> except ClientError as e:
# --> <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/transfer.py?line=293'>294</a>     raise S3UploadFailedError(
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/transfer.py?line=294'>295</a>         "Failed to upload {} to {}: {}".format(
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/transfer.py?line=295'>296</a>             filename, '/'.join([bucket, key]), e
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/transfer.py?line=296'>297</a>         )
#     <a href='file:///home/chase/miniconda3/envs/7643/lib/python3.9/site-packages/boto3/s3/transfer.py?line=297'>298</a>     )
#
# S3UploadFailedError: Failed to upload /tmp/pytorch-example/cifar-10-data/cifar-10-python.tar.gz to Lidar/Lidar-data/cifar-10-python.tar.gz: An error occurred (NoSuchBucket) when calling the CreateMultipartUpload operation: The specified bucket does not exist
